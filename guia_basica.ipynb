# %% [markdown]
# # Esto es un notebook y esta celda está escrita en formato "Markdown" (.md)
# ## La finalidad de este notebook es mostrar mi flujo de trabajo para la tarea 3 del curso de verano "Aplicando la investigación".

# %%
# Esta celda está en formato "Code" en lenguaje python (.py)

# %% [raw]
# Esta celda no tiene formato (raw)

# %% [markdown]
# # .Md
# ## En esta celda se pueden colocar imágenes!
#
# Nota: si usamos el lenguaje HTML podemos editar la imagen, por ejemplo hacerla más pequeña sin perder resolución.
# Nota2: la imagen debe estar en el folder, sino, al exportar el notebook como .html la imagen no se verá.
# Nota3: Pandoc no muestra la foto en el pdf al estar escrito como html
#
# <img src="puppy.jpg" style="max-width:40%; height:auto;">
#
# ![Perrito](puppy.jpg){width=40%}
